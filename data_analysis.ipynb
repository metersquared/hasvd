# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import the data
df = pd.read_csv('benchmark_results.csv')

# %%
# Filter the data for the specific M, m, n values
M = 100
N= 200
m = 10
n = 20
omega = 0.1


filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega)]
# Extract the relevant columns
filtered_df = filtered_df[['eps', 'error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight']]
filtered_df['eps_self'] = filtered_df['eps']  # Add a column for plotting eps vs eps

# Define new labels for the plot
label_map = {
    'error': 'Standard SVD',
    'error_dist_naive': 'Distributed Naive',
    'error_dist_tight': 'Distributed Tight',
    'error_inc_naive': 'Incremented Naive',
    'error_inc_tight': 'Incremented Tight',
    'eps_self': '$\epsilon*$'
}

ax = None
for i, col in enumerate(['error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight', 'eps_self']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Prescribed $\epsilon*$')
plt.ylabel('Frobenius Error')
# Reverse the x-axis
plt.gca().invert_xaxis()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_23553/1418728066.py:21: SyntaxWarning: invalid escape sequence '\e'
#   'eps_self': '$\epsilon*$'
# /tmp/ipykernel_23553/1418728066.py:39: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Prescribed $\epsilon*$')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      24 ax = None
#      25 for i, col in enumerate(['error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight', 'eps_self']):
# ---> 26     marker = markers[i % len(markers)] if col != 'eps_self' else None
#      27     ax = filtered_df.plot(
#      28         x='eps',
#      29         y=col,
#    (...)
# ...

# %%
# Filter the data for the specific M, m, n values
M = 100
N= 200
m = 10
n = 20
omega = 0.5


filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega)]
# Extract the relevant columns
filtered_df = filtered_df[['eps', 'error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight']]
filtered_df['eps_self'] = filtered_df['eps']  # Add a column for plotting eps vs eps

# Define new labels for the plot
label_map = {
    'error': 'Standard SVD',
    'error_dist_naive': 'Distributed Naive',
    'error_dist_tight': 'Distributed Tight',
    'error_inc_naive': 'Incremented Naive',
    'error_inc_tight': 'Incremented Tight',
    'eps_self': '$\epsilon*$'
}

ax = None
for i, col in enumerate(['error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight', 'eps_self']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Prescribed $\epsilon*$')
plt.ylabel('Frobenius Error')
# Reverse the x-axis
plt.gca().invert_xaxis()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_270506/1356914426.py:21: SyntaxWarning: invalid escape sequence '\e'
#   'eps_self': '$\epsilon*$'
# /tmp/ipykernel_270506/1356914426.py:39: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Prescribed $\epsilon*$')

# %%
# Filter the data for the specific M, m, n values
M = 100
N= 200
m = 10
n = 20
omega = 0.9


filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega)]
# Extract the relevant columns
filtered_df = filtered_df[['eps', 'error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight']]
filtered_df['eps_self'] = filtered_df['eps']  # Add a column for plotting eps vs eps

# Define new labels for the plot
label_map = {
    'error': 'Standard SVD',
    'error_dist_naive': 'Distributed Naive',
    'error_dist_tight': 'Distributed Tight',
    'error_inc_naive': 'Incremented Naive',
    'error_inc_tight': 'Incremented Tight',
    'eps_self': '$\epsilon*$'
}

ax = None
for i, col in enumerate(['error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight', 'eps_self']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Prescribed $\epsilon*$')
plt.ylabel('Frobenius Error')
# Reverse the x-axis
plt.gca().invert_xaxis()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_270506/794631002.py:21: SyntaxWarning: invalid escape sequence '\e'
#   'eps_self': '$\epsilon*$'
# /tmp/ipykernel_270506/794631002.py:39: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Prescribed $\epsilon*$')

# %%
# Filter the data for the specific M, m, n values
M = 100
N= 200
m = 10
n = 20
omega = 0.1


filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega)]
# Extract the relevant columns
filtered_df = filtered_df[['eps', 'error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight']]
filtered_df['eps_self'] = filtered_df['eps']  # Add a column for plotting eps vs eps

# Define new labels for the plot
label_map = {
    'error': 'Standard SVD',
    'error_dist_naive': 'Distributed Naive',
    'error_dist_tight': 'Distributed Tight',
    'error_inc_naive': 'Incremented Naive',
    'error_inc_tight': 'Incremented Tight',
    'eps_self': '$\epsilon*$'
}

ax = None
for i, col in enumerate(['error', 'error_dist_naive', 'error_dist_tight', 'error_inc_naive', 'error_inc_tight', 'eps_self']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Prescribed $\epsilon*$')
plt.ylabel('Frobenius Error')
# Reverse the x-axis
plt.gca().invert_xaxis()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:39: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_270506/916301437.py:21: SyntaxWarning: invalid escape sequence '\e'
#   'eps_self': '$\epsilon*$'
# /tmp/ipykernel_270506/916301437.py:39: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Prescribed $\epsilon*$')

# %%
# Filter the data for the specific M, m, n values
N = 200
m = 20
n = 20
omega = 0.1
eps = 0.001

filtered_df = df[(df['N'] == N) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega) & (df['eps'] == eps)]
# Extract the relevant columns
filtered_df = filtered_df[['M', 'rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']]

# Define new labels for the plot
label_map = {
    'rt': 'Standard SVD',
    'rt_dist_naive': 'Distributed Naive',
    'rt_dist_tight': 'Distributed Tight',
    'rt_inc_naive': 'Incremented Naive',
    'rt_inc_tight': 'Incremented Tight'
}

ax = None
for i, col in enumerate(['rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='M',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.xscale('log')
plt.yscale('log')
plt.xlabel('M')
plt.ylabel('Runtime (s)')
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
# Filter the data for the specific M, m, n values
M = 200
m = 20
n = 20
omega = 0.9
eps = 0.001

filtered_df = df[(df['M'] == M) & (df['m'] == m) & (df['n'] == n) & (df['omega'] == omega) & (df['eps'] == eps)]
# Extract the relevant columns
filtered_df = filtered_df[['N', 'rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']]

# Define new labels for the plot
label_map = {
    'rt': 'Standard SVD',
    'rt_dist_naive': 'Distributed Naive',
    'rt_dist_tight': 'Distributed Tight',
    'rt_inc_naive': 'Incremented Naive',
    'rt_inc_tight': 'Incremented Tight'
}

ax = None
for i, col in enumerate(['rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='N',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.xscale('log')
plt.yscale('log')
plt.xlabel('N')
plt.ylabel('Runtime (s)')
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
# Filter the data for the specific M, m, n values
M = 200
N = 200
m = 10
omega = 0.1
eps = 0.001

filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['m'] == m) & (df['omega'] == omega) & (df['eps'] == eps)]
# Extract the relevant columns
filtered_df = filtered_df[['n', 'rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']]

# Define new labels for the plot
label_map = {
    'rt': 'Standard SVD',
    'rt_dist_naive': 'Distributed Naive',
    'rt_dist_tight': 'Distributed Tight',
    'rt_inc_naive': 'Incremented Naive',
    'rt_inc_tight': 'Incremented Tight'
}

ax = None
for i, col in enumerate(['rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='n',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.xlabel('n')
plt.ylabel('Runtime (s)')
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
# Filter the data for the specific M, m, n values
M = 50
N =50
n = 10
omega = 0.9
eps = 0.001

filtered_df = df[(df['M'] == M) & (df['N'] == N) & (df['n'] == n) & (df['omega'] == omega) & (df['eps'] == eps)]
# Extract the relevant columns
filtered_df = filtered_df[['m', 'rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']]

# Define new labels for the plot
label_map = {
    'rt': 'Standard SVD',
    'rt_dist_naive': 'Distributed Naive',
    'rt_dist_tight': 'Distributed Tight',
    'rt_inc_naive': 'Incremented Naive',
    'rt_inc_tight': 'Incremented Tight'
}

ax = None
for i, col in enumerate(['rt', 'rt_dist_naive', 'rt_dist_tight', 'rt_inc_naive', 'rt_inc_tight']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='m',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.xlabel('m')
plt.ylabel('Runtime (s)')
# Out:
# Text(0, 0.5, 'Runtime (s)')

# %%
# Import the data
df2 = pd.read_csv('benchmark_results_2.csv')

# Filter the data for the specific M, m, n values
M = 100
N= 200
m = 10
n = 20
omega = 0.1


filtered_df = df2[(df2['M'] == M) & (df2['N'] == N) & (df2['m'] == m) & (df2['n'] == n) & (df2['omega'] == omega)]
# Extract the relevant columns
filtered_df = filtered_df[['eps', 'rk', 'rk_dist_naive', 'rk_dist_tight', 'rk_inc_naive', 'rk_inc_tight']]

# Define new labels for the plot
label_map = {
    'rk': 'Standard SVD',
    'rk_dist_naive': 'Distributed Naive',
    'rk_dist_tight': 'Distributed Tight',
    'rk_inc_naive': 'Incremented Naive',
    'rk_inc_tight': 'Incremented Tight',
    'eps_self': '$\epsilon*$'
}

# Define markers, colors, and linestyles
markers = ['o', 's', '^', 'D', 'v']  # Circle, square, triangle_up, diamond, triangle_down
colors = ['blue', 'green', 'red', 'purple', 'orange', 'black']
linestyles = ['-', '--', '-.', ':', (0, (3, 1, 1, 1))]  # Solid, dashed, dash-dot, dotted, custom dash

ax = None
for i, col in enumerate(['rk', 'rk_dist_naive', 'rk_dist_tight', 'rk_inc_naive', 'rk_inc_tight']):
    marker = markers[i % len(markers)] if col != 'eps_self' else None
    ax = filtered_df.plot(
        x='eps',
        y=col,
        ax=ax,
        label=label_map[col],
        marker=marker,
        color=colors[i % len(colors)],
        linestyle=linestyles[i % len(linestyles)]
    )
# Logplot the y-axis and x-axis
plt.xscale('log')
plt.xlabel('Prescribed $\epsilon*$')
plt.ylabel('Approximation rank')
# Reverse the x-axis
plt.gca().invert_xaxis()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\e'
# <>:45: SyntaxWarning: invalid escape sequence '\e'
# <>:23: SyntaxWarning: invalid escape sequence '\e'
# <>:45: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_23553/1986734043.py:23: SyntaxWarning: invalid escape sequence '\e'
#   'eps_self': '$\epsilon*$'
# /tmp/ipykernel_23553/1986734043.py:45: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('Prescribed $\epsilon*$')
